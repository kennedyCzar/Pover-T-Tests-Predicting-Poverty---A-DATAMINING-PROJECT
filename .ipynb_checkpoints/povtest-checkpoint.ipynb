# %%
# %matplotlib inline
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
os.chdir('C:/Users/kennedy/Desktop/MyUJMDocs/Data Mining/DataMinin_Project/DataSets')

# %%
A_train = pd.read_csv('A_hhold_train.csv')
B_train = pd.read_csv('B_hhold_train.csv')
C_train = pd.read_csv('C_hhold_train.csv')
#-----------------------------------------
A_test = pd.read_csv('A_hhold_test.csv')
B_test = pd.read_csv('A_hhold_test.csv')
C_test = pd.read_csv('A_hhold_test.csv')
#--------------------------------------
A_train.set_index('id', inplace = True)
B_train.set_index('id', inplace = True)
C_train.set_index('id', inplace = True)
#-----------------------------------------------
A_test.set_index('id', inplace = True)
B_test.set_index('id', inplace = True)
C_test.set_index('id', inplace = True)

# %%
A_test.head()
# Out:
#       wBXbHZmp SlDKnCuu KAJOWiiw DsKacCdL rtPrBBPl tMJrvvut jdetlNNF maLAYXwi  \
# id
# 418      JhtDR    GUusz    TuovO    ZYabk    uxuSS    PHMVg    NDTCU    sehIp
# 41249    JhtDR    alLXR    BIZns    ZYabk    uxuSS    PHMVg    NDTCU    sehIp
# 16205    JhtDR    alLXR    BIZns    ZYabk    feupP    PHMVg    NDTCU    sehIp
# 97501    JhtDR    alLXR    BIZns    ZYabk    feupP    VYpgU    NDTCU    TcuXF
# 67756    JhtDR    GUusz    BIZns    ZYabk    feupP    PHMVg    NDTCU    sehIp
#
#       vwpsXRGk sArDRIyX   ...   sDGibZrP CsGvKKBJ OLpGAaEu LrDrWRjC JCDeZBXq  \
# id                        ...
# 418      XHmQd    MwLvg   ...      JqHnW    MaXfS    USRak    idRwx    UyAms
# 41249    hmAUm    MwLvg   ...      JqHnW    jkHEU    USRak    idRwx    UyAms
# 16205    VJaVA    MwLvg   ...      JqHnW    MaXfS    USRak    idRwx    UyAms
# 97501    IJnCs    MwLvg   ...      JqHnW    MaXfS    HxnJy    idRwx    UyAms
# 67756    puHHm    MwLvg   ...      JqHnW    MaXfS    HxnJy    idRwx    UyAms
# ...

# %%
A_train.info()
B_train.info()
C_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8203 entries, 46107 to 39832
# Columns: 345 entries, wBXbHZmp to country
# dtypes: bool(1), float64(2), int64(2), object(340)
# memory usage: 11.0+ MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3255 entries, 57071 to 4923
# Columns: 442 entries, RzaXNcgd to country
# dtypes: bool(1), float64(9), int64(14), object(418)
# memory usage: 5.8+ MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6469 entries, 57211 to 7646
# Columns: 164 entries, GRGAYimk to country
# dtypes: bool(1), float64(1), int64(29), object(133)
# memory usage: 4.8+ MB

# %%
A_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4041 entries, 418 to 43344
# Columns: 344 entries, wBXbHZmp to country
# dtypes: float64(2), int64(2), object(340)
# memory usage: 5.4+ MB

# %%
A_train.poor.value_counts().plot.bar(title = 'Numb of poor in A')

# %%
#Data preprocessing
from sklearn.preprocessing import Normalizer
from sklearn.preprocessing import StandardScaler

def standardized(df, numeric_only = True):
    numeric = df.select_dtypes(include=['int64', 'float64', 'uint8', 'float32', 'int32'])
    #subtract mean and divide by the standard deviation
    df[numeric.columns] = (numeric - numeric.mean()) / numeric.std()
    return df

def pre_processing_data(df, enforce_cols = None):
    print('Input shape: \t{}'.format(df.shape))
    df = standardized(df)
    print('After standardization {}'.format(df.shape))
    #create dummy variable for the categories
    df = pd.get_dummies(df)
    print('After converting categoricals: \t{}'.format(df.shape))
    
    #match the test and training set
    if enforce_cols is not None:
        to_drop = np.setdiff1d(df.columns, enforce_cols)
        to_add = np.setdiff1d(enforce_cols, df.columns)
        
        df.drop(to_drop, axis = 1, inplace = True)
        df = df.assign(**{c: 0 for c in to_add})
        
    df.fillna(0, inplace= True)
    
    return df

# %%
#here we convert the data to surveys
print("Country A")
AX_train = pre_processing_data(A_train.drop('poor', axis = 1))
AY_train = np.ravel(A_train.poor)

print("\nCountry B")
BX_train = pre_processing_data(B_train.drop('poor', axis = 1))
BY_train = np.ravel(B_train.poor)

print("\nCountry C")
CX_train = pre_processing_data(C_train.drop('poor', axis = 1))
CY_train = np.ravel(C_train.poor)
#------------------------------------------------------
'''
print("Country A_test")
AX_test = pre_processing_data(A_test.drop('poor', axis = 1))
AY_test = np.ravel(A_test.poor)

print("\nCountry B")
BX_test = pre_processing_data(B_test.drop('poor', axis = 1))
BY_test = np.ravel(B_test.poor)

print("\nCountry C")
CX_test = pre_processing_data(C_test.drop('poor', axis = 1))
CY_test = np.ravel(C_test.poor)
'''
# Out:
# Country A
# Input shape: 	(8203, 344)
# After standardization (8203, 344)
# After converting categoricals: 	(8203, 859)
#
# Country B
# Input shape: 	(3255, 441)
# After standardization (3255, 441)
# After converting categoricals: 	(3255, 1432)
#
# Country C
# Input shape: 	(6469, 163)
# After standardization (6469, 163)
# After converting categoricals: 	(6469, 795)
# '\nprint("Country A_test")\nAX_test = pre_processing_data(A_test.drop(\'poor\', axis = 1))\nAY_test = np.ravel(A_test.poor)\n\nprint("\nCountry B")\nBX_test = pre_processing_data(B_test.drop(\'poor\', axis = 1))\nBY_test = np.ravel(B_test.poor)\n\nprint("\nCountry C")\nCX_test = pre_processing_data(C_test.drop(\'poor\', axis = 1))\nCY_test = np.ravel(C_test.poor)\n'

# %%
AX_train.to_csv('AX_train.csv')
AX_train.head()
# Out:
#        nEsgxvAq  OMtioXZZ  YFMZwKrU  TiwRslOh  wBXbHZmp_DkQlr  wBXbHZmp_JhtDR  \
# id
# 46107 -1.447160  0.325746  1.099716 -0.628045               0               1
# 82739 -0.414625 -0.503468 -0.016050  0.713467               0               1
# 9646   0.617910 -0.503468 -0.016050 -0.628045               0               1
# 10975  0.617910 -1.332682 -1.131816  0.713467               0               1
# 16463  0.617910  0.325746 -1.131816 -0.180874               0               1
#
#        SlDKnCuu_GUusz  SlDKnCuu_alLXR  KAJOWiiw_BIZns  KAJOWiiw_TuovO  \
# id
# 46107               1               0               0               1
# 82739               1               0               0               1
# 9646                1               0               1               0
# 10975               1               0               0               1
# 16463               0               1               0               1
#
# ...

# %%
AX_train.head()
# Out:
#        nEsgxvAq  OMtioXZZ  YFMZwKrU  TiwRslOh  wBXbHZmp_DkQlr  wBXbHZmp_JhtDR  \
# id
# 46107 -1.447160  0.325746  1.099716 -0.628045               0               1
# 82739 -0.414625 -0.503468 -0.016050  0.713467               0               1
# 9646   0.617910 -0.503468 -0.016050 -0.628045               0               1
# 10975  0.617910 -1.332682 -1.131816  0.713467               0               1
# 16463  0.617910  0.325746 -1.131816 -0.180874               0               1
#
#        SlDKnCuu_GUusz  SlDKnCuu_alLXR  KAJOWiiw_BIZns  KAJOWiiw_TuovO  \
# id
# 46107               1               0               0               1
# 82739               1               0               0               1
# 9646                1               0               1               0
# 10975               1               0               0               1
# 16463               0               1               0               1
#
# ...

# %%
BX_train.head()
# Out:
#        wJthinfa  ZvEApWrk  vuQrLzvK  FGWqGkmD  qrOrXLPM  BXOWgPgL  umkFMfvA  \
# id
# 57071 -0.060772  0.065928  0.687955       0.0 -0.890950  0.000000       0.0
# 18973 -0.412754 -0.928796  1.034898       0.0 -0.890950  0.000000       0.0
# 20151 -0.412754  2.055376  1.104287       0.0  0.258037  0.000000       0.0
# 5730   0.643192  0.397503 -1.130026       0.0  0.258037 -0.067086       0.0
# 35033  3.459047 -0.265647 -0.991249       0.0  0.258037 -1.271564       0.0
#
#        McFBIGsm  NjDdhqIe  rCVqiShm    ...      rljjAmaN_akDoa  \
# id                                     ...
# 57071  0.000000  0.087650  0.569923    ...                   0
# 18973  0.000000 -0.891198  0.192433    ...                   0
# 20151  0.000000  2.045347  0.720918    ...                   0
# 5730   0.024975  0.413933  0.003688    ...                   0
# 35033 -1.899275 -0.238632  0.381178    ...                   0
#
#        rljjAmaN_fEsQq  rljjAmaN_gPPdN  ChbSWYhO_BgSQe  ChbSWYhO_Enull  \
# id
# ...

# %%
CX_train.head()
# Out:
#        LhUIIEHQ  PNAiwXUz  jmsRIiqp  NONtAKOM  kLAQgdly  WWuPOkor  CtFxPQPT  \
# id
# 57211 -0.606739 -0.350340 -0.313847 -0.310077 -0.704307  0.524039  0.380397
# 62519 -0.606739  3.907434 -0.313847  0.249445 -0.390493  0.524039 -3.296468
# 11614  0.742520 -0.299653  0.449989  0.808967  1.004237  0.524039  0.380397
# 6470   0.742520 -0.350340 -1.077683  0.808967  1.004237  0.524039  0.292852
# 33558  0.742520  0.004474  0.449989 -0.310077 -0.094113 -1.142633  0.424169
#
#        GIwNbAsH  qLDzvjiU  detlNNFh    ...      lAvdypjD_SnGME  \
# id                                     ...
# 57211  0.026222 -0.249567 -0.127064    ...                   0
# 62519  0.026222 -0.249567 -0.127064    ...                   0
# 11614 -0.444972  0.541055 -0.127064    ...                   0
# 6470  -0.444972 -1.040189 -0.127064    ...                   0
# 33558 -0.444972 -0.249567  0.184764    ...                   0
#
#        lAvdypjD_UUKOE  lAvdypjD_gWylU  lAvdypjD_jSoky  ARWytYMz_NwjRA  \
# id
# ...

# %%
from sklearn.ensemble import RandomForestClassifier

#this is basic implementation of the random forest
def train_model(features, labels, **kwargs):
    #instantiate the model
    model = RandomForestClassifier(n_estimators = 50, random_state = 0)
    #train model
    model.fit(features, labels)
    
    #get a not very useful sense of performance
    accuracy = model.score(features, labels)
    print(f"In-sample accuracy: {accuracy: 0.20%}")
    
    return model

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from mlxtend.classifier import StackingClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import GradientBoostingClassifier
import xgboost as xgb
from xgboost.sklearn import XGBClassifier
from keras.models import Sequential
from keras.layers import Dense

'''
    for final_model, label in zip([model0, model1, model3, model4, model5, comb_model], 
                      ['DecisionTree', 
                       'AdaBoostClassifier', 
                       'KNeighbors',
                       'GaussianNB',
                      'LogisticRegression',
                      'Stacking_GradientBst']):
'''
def train_combined_modelA(features, labels, **kwargs):
    #model0 = DecisionTreeClassifier(max_depth=None, random_state = 0)
    model1 = AdaBoostClassifier(base_estimator = None, n_estimators = 50, learning_rate = 1.0, random_state = 0)
    model2 = GradientBoostingClassifier(n_estimators = 50, learning_rate = 1.0, random_state = 0)
    model3 = KNeighborsClassifier(n_neighbors=1)
    #model4 = GaussianNB()
    model5 = LogisticRegression()
    model6 = RandomForestClassifier(n_estimators = 50, random_state = 0)
    
    comb_model = StackingClassifier(classifiers=[model1, model5, model6, model3], meta_classifier = model2)    
    comb_model.fit(features, labels)
    accuracy = comb_model.score(features, labels)
    print(f"Accuracy: {accuracy: 0.20%}")
    return comb_model

def train_combined_modelB(features, labels, **kwargs):
    md1 = RandomForestClassifier(n_estimators = 50, random_state = 0)
    md2 = LogisticRegression()
    #md2 = AdaBoostClassifier(base_estimator = None, n_estimators = 50, learning_rate = 1.0, random_state = 0)
    md3 = GradientBoostingClassifier(n_estimators = 50, learning_rate = 1.0, random_state = 0)
    
    comb_model = StackingClassifier(classifiers=[md1, md2], meta_classifier = md3)
    comb_model.fit(features, labels)
    accuracy = comb_model.score(features, labels)
    print(f"Accuracy: {accuracy: 0.10%}")
    return comb_model
    
def train_combined_modelC(features, labels, **kwargs):
    md1 = RandomForestClassifier(n_estimators = 50, random_state = 0)
    md2 = AdaBoostClassifier(base_estimator = None, n_estimators = 50, learning_rate = 1.0, random_state = 0)
    md3 = GradientBoostingClassifier(n_estimators = 50, learning_rate = 1.0, random_state = 0)
    
    comb_model = StackingClassifier(classifiers=[md1, md2], meta_classifier = md3)
    comb_model.fit(features, labels)
    accuracy = comb_model.score(features, labels)
    print(f"Accuracy: {accuracy: 0.10%}")
    return comb_model

#def neural_net(features, labels, **kwargs):
# Out:
# Using TensorFlow backend.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-28-bd5d01488178> in <module>()
#       9 import xgboost as xgb
#      10 from xgboost.sklearn import XGBClassifier
# ---> 11 from keras.models import Sequential
#      12 from keras.layers import Dense
#      13
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\__init__.py in <module>()
#       1 from __future__ import absolute_import
#       2
# ----> 3 from . import utils
#       4 from . import activations
#       5 from . import applications
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\utils\__init__.py in <module>()
#       4 from . import data_utils
#       5 from . import io_utils
# ----> 6 from . import conv_utils
#       7
#       8 # Globally-importable utils.
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\utils\conv_utils.py in <module>()
# ...

# %%
#first model A
model_A = train_combined_modelA(AX_train, AY_train)

# %%
#second model B
model_B = train_combined_modelA(BX_train, BY_train)

# %%
#third model C
model_C = train_combined_modelA(CX_train, CY_train)

# %%
#process the data
A_test = pre_processing_data(A_test, enforce_cols = AX_train.columns)
B_test = pre_processing_data(B_test, enforce_cols = BX_train.columns)
C_test = pre_processing_data(C_test, enforce_cols = CX_train.columns)
A_test.head()

# %%
'''
from sklearn.model_selection import cross_val_predict
from sklearn import metrics
pred = cross_val_predict(model_A, AX_train, AY_train, cv=10)
#print(metrics.accuracy_score(AY_train, pred))
'''

#submission format

A_pred = model_A.predict_proba(A_test)
B_pred = model_B.predict_proba(B_test)
C_pred = model_C.predict_proba(C_test)

# %%
print(A_pred)
print(B_pred)
print(C_pred)

# %%
def country_sub(preds, test_feat, country):
    #make sure the codes for the country are correct
    country_codes = ['A', 'B', 'C']
    
    country_sub = pd.DataFrame(data = preds[:,1], columns = ['poor'], index = test_feat.index)
    country_sub["country"] = country
    return country_sub[["country", "poor"]]

# %%
A_sub = country_sub(A_pred, A_test, 'A')
B_sub = country_sub(B_pred, B_test, 'B')
C_sub = country_sub(C_pred, C_test, 'C')

# %%
A_sub.head()

# %%
submission = pd.concat([A_sub, B_sub, C_sub])

# %%
submission.poor.value_counts().plot.bar(title = 'Number of poor for country A, B, C')

# %%
submission.tail()

# %%
sub_neu.tail()

# %%
submission.tail()

# %%
submission.to_csv('submission.csv')

# %%
submission.info()
